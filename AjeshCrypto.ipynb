# %% [markdown]
# # 1.Setup

# %%
# !pip install python-binance pandas mplfinance
# Out:
# Requirement already satisfied: python-binance in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (1.0.28)
# Requirement already satisfied: pandas in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: mplfinance in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (0.12.10b0)
# Requirement already satisfied: requests in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from python-binance) (2.31.0)
# Requirement already satisfied: six in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from python-binance) (1.17.0)
# Requirement already satisfied: dateparser in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from python-binance) (1.2.1)
# Requirement already satisfied: aiohttp in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from python-binance) (3.11.13)
# Requirement already satisfied: websockets in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from python-binance) (15.0)
# Requirement already satisfied: pycryptodome in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from python-binance) (3.21.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: matplotlib in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from mplfinance) (3.10.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->python-binance) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->python-binance) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->python-binance) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->python-binance) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->python-binance) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->python-binance) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->python-binance) (1.18.3)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from dateparser->python-binance) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from dateparser->python-binance) (5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mplfinance) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mplfinance) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mplfinance) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mplfinance) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mplfinance) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mplfinance) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from requests->python-binance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from requests->python-binance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from requests->python-binance) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from requests->python-binance) (2023.11.17)

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: et-xmlfile in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\ajesh guleria\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Fetching and cleaning data

# %%
from binance import Client ,ThreadedDepthCacheManager, ThreadedWebsocketManager
import pandas as pd

# %%
import requests
import csv

# %%
import requests
import pandas as pd

def fetch_crypto_data():
    """
    Fetches the top 50 cryptocurrency data from CoinGecko and Binance APIs 
    and returns a Pandas DataFrame.
    """
    # Step 1: Fetch top cryptocurrencies from CoinGecko
    coingecko_url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        "vs_currency": "usd",
        "order": "market_cap_desc",
        "per_page": 78,  # Fetch extra to compensate for missing ones
        "page": 1,
        "sparkline": False
    }

    response = requests.get(coingecko_url, params=params)

    # Step 2: Validate API response
    if response.status_code != 200:
        print("Error:", response.status_code, response.text)
        return None

    try:
        top_cryptos = response.json()  # Convert response to JSON
    except ValueError:
        print("Error: Unable to parse JSON. Response:", response.text)
        return None

    if not isinstance(top_cryptos, list):
        print("Unexpected response format:", top_cryptos)
        return None

    # Step 3: Fetch Binance data
    binance_url = "https://api.binance.com/api/v3/ticker/24hr"
    crypto_data = []

    for crypto in top_cryptos:
        if not isinstance(crypto, dict):
            continue

        symbol = crypto.get("symbol", "").upper() + "USDT"

        binance_response = requests.get(binance_url, params={"symbol": symbol})

        if binance_response.status_code == 200:
            try:
                binance_data = binance_response.json()
            except ValueError:
                continue

            if isinstance(binance_data, dict) and "lastPrice" in binance_data:
                crypto_info = {
                    "Cryptocurrency Name": crypto.get("name", "N/A"),
                    "Symbol": symbol,
                    "Current Price (USD)": float(binance_data["lastPrice"]),
                    "Market Cap $": float(crypto.get('market_cap', 0)),
                    "24-hour Trading Volume": float(binance_data.get('quoteVolume', 0)),
                    "24-hour Price Change (%)": float(binance_data.get('priceChangePercent', 0))
                }
                crypto_data.append(crypto_info)

        if len(crypto_data) == 50:  # Stop after collecting 50 cryptos
            break

    # Convert to DataFrame
    df = pd.DataFrame(crypto_data)

    return df

# %%
crypto_df = fetch_crypto_data()
crypto_df
# Out:
#                       Cryptocurrency Name      Symbol  Current Price (USD)  \
# 0                                 Bitcoin     BTCUSDT         85106.910000
# 1                                Ethereum     ETHUSDT          2196.340000
# 2                                     XRP     XRPUSDT             2.224900
# 3                                     BNB     BNBUSDT           603.250000
# 4                                  Solana     SOLUSDT           140.760000
# 5                                    USDC    USDCUSDT             1.000300
# 6                                Dogecoin    DOGEUSDT             0.202410
# 7                                 Cardano     ADAUSDT             0.647400
# 8                                    TRON     TRXUSDT             0.234600
# 9                         Wrapped Bitcoin    WBTCUSDT         84993.250000
# 10                                 Hedera    HBARUSDT             0.245830
# 11                                Stellar     XLMUSDT             0.311400
# 12                              Chainlink    LINKUSDT            14.470000
# 13                              Avalanche    AVAXUSDT            21.700000
# 14                               Litecoin     LTCUSDT           118.530000
# 15                                    Sui     SUIUSDT             2.800200
# 16                                Toncoin     TONUSDT             3.300000
# 17                              Shiba Inu    SHIBUSDT             0.000014
# 18                                   USDS    USDSUSDT             0.000000
# 19                                 MANTRA      OMUSDT             7.494400
# 20                               Polkadot     DOTUSDT             4.594000
# 21                           Bitcoin Cash     BCHUSDT           316.100000
# 22                                Uniswap     UNIUSDT             7.359000
# 23                                 Monero     XMRUSDT             0.000000
# 24                          NEAR Protocol    NEARUSDT             3.192000
# 25                                  Aptos     APTUSDT             6.190000
# 26                                    Dai     DAIUSDT             0.000000
# 27                                   Pepe    PEPEUSDT             0.000008
# 28                      Internet Computer     ICPUSDT             6.545000
# 29                                   Aave    AAVEUSDT           191.770000
# 30                       Ethereum Classic     ETCUSDT            18.960000
# 31                              Bittensor     TAOUSDT           325.400000
# 32                         Official Trump   TRUMPUSDT            13.470000
# 33                         POL (ex-MATIC)     POLUSDT             0.277100
# 34                      Sonic (prev. FTM)       SUSDT             0.724300
# 35                                VeChain     VETUSDT             0.028090
# 36                               Celestia     TIAUSDT             4.158000
# 37                               Algorand    ALGOUSDT             0.245700
# 38                               Filecoin     FILUSDT             3.203000
# 39                      First Digital USD   FDUSDUSDT             0.998800
# 40                                Jupiter     JUPUSDT             0.743000
# 41                             Cosmos Hub    ATOMUSDT             4.430000
# 42                                 Render  RENDERUSDT             3.749000
# 43                               Arbitrum     ARBUSDT             0.412900
# 44                               Optimism      OPUSDT             1.047000
# 45  Artificial Superintelligence Alliance     FETUSDT             0.641000
# 46                                  Maker     MKRUSDT          1636.000000
# 47                                  Quant     QNTUSDT            91.900000
# 48                              Injective     INJUSDT            12.640000
# 49                              Immutable     IMXUSDT             0.691000
#
#     Market Cap $  24-hour Trading Volume  24-hour Price Change (%)
# 0   1.687898e+12            1.265464e+09                     0.452
# 1   2.640031e+11            9.350282e+08                     1.504
# 2   1.292182e+11            3.231168e+08                     3.556
# 3   8.785265e+10            9.678629e+07                     0.490
# 4   7.147415e+10            3.809300e+08                     0.306
# 5   5.634432e+10            3.743226e+08                    -0.010
# 6   2.994422e+10            1.219713e+08                     0.737
# 7   2.326118e+10            6.401940e+07                     2.550
# 8   2.019501e+10            5.514221e+07                     0.773
# 9   1.098643e+10            1.581210e+07                     0.524
# 10  1.034707e+10            1.759949e+08                     6.076
# 11  9.588923e+09            4.576148e+07                     4.427
# 12  9.236419e+09            2.624464e+07                     1.047
# 13  8.969701e+09            3.642580e+07                     2.070
# 14  8.959006e+09            9.170831e+07                    -5.335
# 15  8.904122e+09            1.018993e+08                     0.018
# 16  8.239099e+09            8.937053e+06                     1.726
# 17  7.976287e+09            1.422850e+07                    -0.074
# 18  7.877337e+09            0.000000e+00                     0.000
# 19  7.295443e+09            1.065446e+07                     0.442
# 20  7.002976e+09            1.789833e+07                     0.547
# 21  6.267043e+09            2.260450e+07                     1.968
# 22  4.411924e+09            1.460024e+07                     1.169
# 23  4.136446e+09            0.000000e+00                     0.000
# 24  3.789136e+09            3.289111e+07                     2.604
# 25  3.652539e+09            2.259148e+07                    -3.882
# 26  3.287336e+09            0.000000e+00                     0.000
# 27  3.180956e+09            8.747398e+07                     1.611
# 28  3.152939e+09            8.012032e+06                     2.876
# 29  2.885135e+09            2.008576e+07                     3.130
# 30  2.857764e+09            8.943540e+06                    -0.158
# 31  2.727401e+09            3.896855e+07                     1.529
# 32  2.705958e+09            2.339516e+08                     2.668
# 33  2.375985e+09            7.376259e+06                     3.203
# 34  2.291649e+09            6.823655e+07                     0.000
# 35  2.275203e+09            9.328878e+06                     2.294
# 36  2.230018e+09            1.729402e+07                     0.947
# 37  2.081875e+09            2.096748e+07                     4.154
# 38  2.053007e+09            9.537072e+06                     1.586
# 39  2.037768e+09            3.141539e+08                     0.020
# 40  1.954127e+09            2.510307e+07                     1.323
# 41  1.942853e+09            5.285123e+06                    -0.337
# 42  1.939256e+09            6.025940e+06                     1.709
# 43  1.821763e+09            1.160233e+07                     1.325
# 44  1.693264e+09            1.123840e+07                     0.096
# 45  1.665164e+09            9.873741e+06                     1.585
# 46  1.388021e+09            2.803616e+07                     3.939
# 47  1.335881e+09            1.867852e+06                    -0.756
# 48  1.234729e+09            7.030018e+06                    -0.551
# 49  1.223514e+09            2.555242e+06                    -0.576

# %%
crypto_df.index = range(1, len(crypto_df)+1)
crypto_df
# Out:
#                       Cryptocurrency Name      Symbol  Current Price (USD)  \
# 1                                 Bitcoin     BTCUSDT         85106.910000
# 2                                Ethereum     ETHUSDT          2196.340000
# 3                                     XRP     XRPUSDT             2.224900
# 4                                     BNB     BNBUSDT           603.250000
# 5                                  Solana     SOLUSDT           140.760000
# 6                                    USDC    USDCUSDT             1.000300
# 7                                Dogecoin    DOGEUSDT             0.202410
# 8                                 Cardano     ADAUSDT             0.647400
# 9                                    TRON     TRXUSDT             0.234600
# 10                        Wrapped Bitcoin    WBTCUSDT         84993.250000
# 11                                 Hedera    HBARUSDT             0.245830
# 12                                Stellar     XLMUSDT             0.311400
# 13                              Chainlink    LINKUSDT            14.470000
# 14                              Avalanche    AVAXUSDT            21.700000
# 15                               Litecoin     LTCUSDT           118.530000
# 16                                    Sui     SUIUSDT             2.800200
# 17                                Toncoin     TONUSDT             3.300000
# 18                              Shiba Inu    SHIBUSDT             0.000014
# 19                                   USDS    USDSUSDT             0.000000
# 20                                 MANTRA      OMUSDT             7.494400
# 21                               Polkadot     DOTUSDT             4.594000
# 22                           Bitcoin Cash     BCHUSDT           316.100000
# 23                                Uniswap     UNIUSDT             7.359000
# 24                                 Monero     XMRUSDT             0.000000
# 25                          NEAR Protocol    NEARUSDT             3.192000
# 26                                  Aptos     APTUSDT             6.190000
# 27                                    Dai     DAIUSDT             0.000000
# 28                                   Pepe    PEPEUSDT             0.000008
# 29                      Internet Computer     ICPUSDT             6.545000
# 30                                   Aave    AAVEUSDT           191.770000
# 31                       Ethereum Classic     ETCUSDT            18.960000
# 32                              Bittensor     TAOUSDT           325.400000
# 33                         Official Trump   TRUMPUSDT            13.470000
# 34                         POL (ex-MATIC)     POLUSDT             0.277100
# 35                      Sonic (prev. FTM)       SUSDT             0.724300
# 36                                VeChain     VETUSDT             0.028090
# 37                               Celestia     TIAUSDT             4.158000
# 38                               Algorand    ALGOUSDT             0.245700
# 39                               Filecoin     FILUSDT             3.203000
# 40                      First Digital USD   FDUSDUSDT             0.998800
# 41                                Jupiter     JUPUSDT             0.743000
# 42                             Cosmos Hub    ATOMUSDT             4.430000
# 43                                 Render  RENDERUSDT             3.749000
# 44                               Arbitrum     ARBUSDT             0.412900
# 45                               Optimism      OPUSDT             1.047000
# 46  Artificial Superintelligence Alliance     FETUSDT             0.641000
# 47                                  Maker     MKRUSDT          1636.000000
# 48                                  Quant     QNTUSDT            91.900000
# 49                              Injective     INJUSDT            12.640000
# 50                              Immutable     IMXUSDT             0.691000
#
#     Market Cap $  24-hour Trading Volume  24-hour Price Change (%)
# 1   1.687898e+12            1.265464e+09                     0.452
# 2   2.640031e+11            9.350282e+08                     1.504
# 3   1.292182e+11            3.231168e+08                     3.556
# 4   8.785265e+10            9.678629e+07                     0.490
# 5   7.147415e+10            3.809300e+08                     0.306
# 6   5.634432e+10            3.743226e+08                    -0.010
# 7   2.994422e+10            1.219713e+08                     0.737
# 8   2.326118e+10            6.401940e+07                     2.550
# 9   2.019501e+10            5.514221e+07                     0.773
# 10  1.098643e+10            1.581210e+07                     0.524
# 11  1.034707e+10            1.759949e+08                     6.076
# 12  9.588923e+09            4.576148e+07                     4.427
# 13  9.236419e+09            2.624464e+07                     1.047
# 14  8.969701e+09            3.642580e+07                     2.070
# 15  8.959006e+09            9.170831e+07                    -5.335
# 16  8.904122e+09            1.018993e+08                     0.018
# 17  8.239099e+09            8.937053e+06                     1.726
# 18  7.976287e+09            1.422850e+07                    -0.074
# 19  7.877337e+09            0.000000e+00                     0.000
# 20  7.295443e+09            1.065446e+07                     0.442
# 21  7.002976e+09            1.789833e+07                     0.547
# 22  6.267043e+09            2.260450e+07                     1.968
# 23  4.411924e+09            1.460024e+07                     1.169
# 24  4.136446e+09            0.000000e+00                     0.000
# 25  3.789136e+09            3.289111e+07                     2.604
# 26  3.652539e+09            2.259148e+07                    -3.882
# 27  3.287336e+09            0.000000e+00                     0.000
# 28  3.180956e+09            8.747398e+07                     1.611
# 29  3.152939e+09            8.012032e+06                     2.876
# 30  2.885135e+09            2.008576e+07                     3.130
# 31  2.857764e+09            8.943540e+06                    -0.158
# 32  2.727401e+09            3.896855e+07                     1.529
# 33  2.705958e+09            2.339516e+08                     2.668
# 34  2.375985e+09            7.376259e+06                     3.203
# 35  2.291649e+09            6.823655e+07                     0.000
# 36  2.275203e+09            9.328878e+06                     2.294
# 37  2.230018e+09            1.729402e+07                     0.947
# 38  2.081875e+09            2.096748e+07                     4.154
# 39  2.053007e+09            9.537072e+06                     1.586
# 40  2.037768e+09            3.141539e+08                     0.020
# 41  1.954127e+09            2.510307e+07                     1.323
# 42  1.942853e+09            5.285123e+06                    -0.337
# 43  1.939256e+09            6.025940e+06                     1.709
# 44  1.821763e+09            1.160233e+07                     1.325
# 45  1.693264e+09            1.123840e+07                     0.096
# 46  1.665164e+09            9.873741e+06                     1.585
# 47  1.388021e+09            2.803616e+07                     3.939
# 48  1.335881e+09            1.867852e+06                    -0.756
# 49  1.234729e+09            7.030018e+06                    -0.551
# 50  1.223514e+09            2.555242e+06                    -0.576

# %%
row_type= crypto_df.iloc[1].apply(type)
row_type
# Out:
# Cryptocurrency Name                   <class 'str'>
# Symbol                                <class 'str'>
# Current Price (USD)         <class 'numpy.float64'>
# Market Cap $                <class 'numpy.float64'>
# 24-hour Trading Volume      <class 'numpy.float64'>
# 24-hour Price Change (%)    <class 'numpy.float64'>
# Name: 2, dtype: object

# %% [markdown]
# # Data Analysis

# %% [markdown]
# #### > Top 5 cryptocurrencies by market cap

# %%
crypto_df["Market Cap $"] = crypto_df["Market Cap $"].replace('[\$,]', '', regex=True).astype(float)
top_5 = crypto_df.nlargest(5,'Market Cap $')
top_5
# Out:
#   Cryptocurrency Name   Symbol  Current Price (USD)  Market Cap $  \
# 1             Bitcoin  BTCUSDT           85106.9100  1.687898e+12
# 2            Ethereum  ETHUSDT            2196.3400  2.640031e+11
# 3                 XRP  XRPUSDT               2.2249  1.292182e+11
# 4                 BNB  BNBUSDT             603.2500  8.785265e+10
# 5              Solana  SOLUSDT             140.7600  7.147415e+10
#
#    24-hour Trading Volume  24-hour Price Change (%)
# 1            1.265464e+09                     0.452
# 2            9.350282e+08                     1.504
# 3            3.231168e+08                     3.556
# 4            9.678629e+07                     0.490
# 5            3.809300e+08                     0.306

# %% [markdown]
# #### > Calculating the average current price of Top 50 Cryptocurrencies

# %%
Average_price = crypto_df["Current Price (USD)"].mean()
Average_price
# Out:
# np.float64(3517.382807022)

# %% [markdown]
# #### Highest and lowest 24-hour percentage price

# %%
highest_change = crypto_df.loc[crypto_df["24-hour Price Change (%)"].idxmax()]
lowest_change = crypto_df.loc[crypto_df["24-hour Price Change (%)"].idxmin()]

# %%
highest_change
# Out:
# Cryptocurrency Name                  Hedera
# Symbol                             HBARUSDT
# Current Price (USD)                 0.24583
# Market Cap $                  10347074633.0
# 24-hour Trading Volume      175994870.94834
# 24-hour Price Change (%)              6.076
# Name: 11, dtype: object

# %%
lowest_change
# Out:
# Cryptocurrency Name               Litecoin
# Symbol                             LTCUSDT
# Current Price (USD)                 118.53
# Market Cap $                  8959006297.0
# 24-hour Trading Volume      91708312.41952
# 24-hour Price Change (%)            -5.335
# Name: 15, dtype: object

# %%
from openpyxl import load_workbook
import time

# %%
def update_excel(df, file_name="crypto_data.xlsx"):
    try:
        # Load existing workbook
        book = load_workbook(file_name)
        writer = pd.ExcelWriter(file_name, engine="openpyxl", mode="a", if_sheet_exists="replace")
    except FileNotFoundError:
        # Create a new file if not found
        writer = pd.ExcelWriter(file_name, engine="openpyxl")

    # Write data
    df.to_excel(writer, sheet_name="Live Data", index=False)

    # Save file
    writer.close()
    print("Excel updated successfully.")

# %%
# Simulate fetching and updating every 5 minutes
while True:
    # Fetch latest data (use your existing fetching function)
    df = fetch_crypto_data()  # Replace with your function

    # Update the Excel file
    if df is not None:
        update_excel(df)
        
    # Wait for 5 minutes before updating again
    time.sleep(300)
# Out:
# Excel updated successfully.
